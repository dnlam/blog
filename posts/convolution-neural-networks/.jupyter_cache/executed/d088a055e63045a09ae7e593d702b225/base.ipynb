# %%
# imports
import os
import sys
import types
import json
import base64

# figure size/format
fig_width = 7
fig_height = 5
fig_format = 'retina'
fig_dpi = 96
interactivity = ''
is_shiny = False
is_dashboard = False
plotly_connected = True

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = "figure"

  # IPython 7.14 deprecated set_matplotlib_formats from IPython
  try:
    from matplotlib_inline.backend_inline import set_matplotlib_formats
  except ImportError:
    # Fall back to deprecated location for older IPython versions
    from IPython.display import set_matplotlib_formats
    
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  if plotly_connected:
    pio.renderers.default = "notebook_connected"
  else:
    pio.renderers.default = "notebook"
  for template in pio.templates.keys():
    pio.templates[template].layout.margin = dict(t=30,r=0,b=0,l=0)
except Exception:
  pass

# disable itables paging for dashboards
if is_dashboard:
  try:
    from itables import options
    options.dom = 'fiBrtlp'
    options.maxBytes = 1024 * 1024
    options.language = dict(info = "Showing _TOTAL_ entries")
    options.classes = "display nowrap compact"
    options.paging = False
    options.searching = True
    options.ordering = True
    options.info = True
    options.lengthChange = False
    options.autoWidth = False
    options.responsive = True
    options.keys = True
    options.buttons = []
  except Exception:
    pass
  
  try:
    import altair as alt
    # By default, dashboards will have container sized
    # vega visualizations which allows them to flow reasonably
    theme_sentinel = '_quarto-dashboard-internal'
    def make_theme(name):
        nonTheme = alt.themes._plugins[name]    
        def patch_theme(*args, **kwargs):
            existingTheme = nonTheme()
            if 'height' not in existingTheme:
              existingTheme['height'] = 'container'
            if 'width' not in existingTheme:
              existingTheme['width'] = 'container'

            if 'config' not in existingTheme:
              existingTheme['config'] = dict()
            
            # Configure the default font sizes
            title_font_size = 15
            header_font_size = 13
            axis_font_size = 12
            legend_font_size = 12
            mark_font_size = 12
            tooltip = False

            config = existingTheme['config']

            # The Axis
            if 'axis' not in config:
              config['axis'] = dict()
            axis = config['axis']
            if 'labelFontSize' not in axis:
              axis['labelFontSize'] = axis_font_size
            if 'titleFontSize' not in axis:
              axis['titleFontSize'] = axis_font_size  

            # The legend
            if 'legend' not in config:
              config['legend'] = dict()
            legend = config['legend']
            if 'labelFontSize' not in legend:
              legend['labelFontSize'] = legend_font_size
            if 'titleFontSize' not in legend:
              legend['titleFontSize'] = legend_font_size  

            # The header
            if 'header' not in config:
              config['header'] = dict()
            header = config['header']
            if 'labelFontSize' not in header:
              header['labelFontSize'] = header_font_size
            if 'titleFontSize' not in header:
              header['titleFontSize'] = header_font_size    

            # Title
            if 'title' not in config:
              config['title'] = dict()
            title = config['title']
            if 'fontSize' not in title:
              title['fontSize'] = title_font_size

            # Marks
            if 'mark' not in config:
              config['mark'] = dict()
            mark = config['mark']
            if 'fontSize' not in mark:
              mark['fontSize'] = mark_font_size

            # Mark tooltips
            if tooltip and 'tooltip' not in mark:
              mark['tooltip'] = dict(content="encoding")

            return existingTheme
            
        return patch_theme

    # We can only do this once per session
    if theme_sentinel not in alt.themes.names():
      for name in alt.themes.names():
        alt.themes.register(name, make_theme(name))
      
      # register a sentinel theme so we only do this once
      alt.themes.register(theme_sentinel, make_theme('default'))
      alt.themes.enable('default')

  except Exception:
    pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass

# interactivity
if interactivity:
  from IPython.core.interactiveshell import InteractiveShell
  InteractiveShell.ast_node_interactivity = interactivity

# NOTE: the kernel_deps code is repeated in the cleanup.py file
# (we can't easily share this code b/c of the way it is run).
# If you edit this code also edit the same code in cleanup.py!

# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
run_path = 'L2hvbWUvZWMyLXVzZXIvcGVyc28vYmxvZy9wb3N0cy9jb252b2x1dGlvbi1uZXVyYWwtbmV0d29ya3M='
if run_path:
  # hex-decode the path
  run_path = base64.b64decode(run_path.encode("utf-8")).decode("utf-8")
  os.chdir(run_path)

# reset state
# %reset

# shiny
# Checking for shiny by using False directly because we're after the %reset. We don't want
# to set a variable that stays in global scope.
if False:
  try:
    import htmltools as _htmltools
    import ast as _ast

    _htmltools.html_dependency_render_mode = "json"

    # This decorator will be added to all function definitions
    def _display_if_has_repr_html(x):
      try:
        # IPython 7.14 preferred import
        from IPython.display import display, HTML
      except:
        from IPython.core.display import display, HTML

      if hasattr(x, '_repr_html_'):
        display(HTML(x._repr_html_()))
      return x

    # ideally we would undo the call to ast_transformers.append
    # at the end of this block whenver an error occurs, we do 
    # this for now as it will only be a problem if the user 
    # switches from shiny to not-shiny mode (and even then likely
    # won't matter)
    import builtins
    builtins._display_if_has_repr_html = _display_if_has_repr_html

    class _FunctionDefReprHtml(_ast.NodeTransformer):
      def visit_FunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

      def visit_AsyncFunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

    ip = get_ipython()
    ip.ast_transformers.append(_FunctionDefReprHtml())

  except:
    pass

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v

  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
globals()["__spec__"] = None
# Out:
# {"/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/importlib/_bootstrap.py": 1757511095.413356, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/importlib/_bootstrap_external.py": 1757511095.413356, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/zipimport.py": 1757511095.6033704, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/codecs.py": 1757511095.343351, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/encodings/aliases.py": 1757511095.3633523, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/encodings/__init__.py": 1757511095.3633523, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/encodings/utf_8.py": 1757511095.373353, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/abc.py": 1757511095.33335, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/io.py": 1757511095.413356, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/stat.py": 1757511095.583369, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/_collections_abc.py": 1757511095.33335, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/genericpath.py": 1757511095.3933547, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/posixpath.py": 1757511095.4333577, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/os.py": 1757511095.4333577, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/_sitebuiltins.py": 1757511095.33335, "/home/ec2-user/perso/.perso/lib/python3.11/site-packages/_virtualenv.py": 1757511096.0434039, "/home/ec2-user/perso/.perso/lib/python3.11/site-packages/_distutils_hack/__init__.py": 1757511109.1343944, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/site.py": 1757511095.5733683, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/warnings.py": 1757511095.5933697, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/importlib/__init__.py": 1757511095.413356, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/importlib/machinery.py": 1757511095.413356, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/importlib/_abc.py": 1757511095.413356, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/keyword.py": 1757511095.413356, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/operator.py": 1757511095.4333577, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/reprlib.py": 1757511095.4333577, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/collections/__init__.py": 1757511095.343351, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/types.py": 1757511095.5933697, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/functools.py": 1757511095.3933547, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/contextlib.py": 1757511095.343351, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/_weakrefset.py": 1757511095.33335, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/threading.py": 1757511095.583369, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/importlib/util.py": 1757511095.413356, "/home/ec2-user/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/runp ...

# %%
#| echo: false
#| output: false
#| eval: true
#| warning: false
from fastai.vision.all import *
from fastai.vision.models import *
import pandas as pd
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

path_imagenette=untar_data(URLs.IMAGENETTE)
path_mnist=untar_data(URLs.MNIST_SAMPLE)
im3 = Image.open(path_mnist/'train'/'3'/'12.png')
show_image(im3)
# Out:
# <Axes: >

# %%
#| echo: false
#| output: true
#| eval: true
#| warning: false

im3_t=tensor(im3)
df = pd.DataFrame(im3_t[:10,:30])
df.style.set_properties(**{'font-size':'6pt'}).background_gradient('Greys')
# Out:
# <style type="text/css">
# #T_afafc_row0_col0, #T_afafc_row0_col1, #T_afafc_row0_col2, #T_afafc_row0_col3, #T_afafc_row0_col4, #T_afafc_row0_col5, #T_afafc_row0_col6, #T_afafc_row0_col7, #T_afafc_row0_col8, #T_afafc_row0_col9, #T_afafc_row0_col10, #T_afafc_row0_col11, #T_afafc_row0_col12, #T_afafc_row0_col13, #T_afafc_row0_col14, #T_afafc_row0_col15, #T_afafc_row0_col16, #T_afafc_row0_col17, #T_afafc_row0_col18, #T_afafc_row0_col19, #T_afafc_row0_col20, #T_afafc_row0_col21, #T_afafc_row0_col22, #T_afafc_row0_col23, #T_afafc_row0_col24, #T_afafc_row0_col25, #T_afafc_row0_col26, #T_afafc_row0_col27, #T_afafc_row1_col0, #T_afafc_row1_col1, #T_afafc_row1_col2, #T_afafc_row1_col3, #T_afafc_row1_col4, #T_afafc_row1_col5, #T_afafc_row1_col6, #T_afafc_row1_col7, #T_afafc_row1_col8, #T_afafc_row1_col9, #T_afafc_row1_col10, #T_afafc_row1_col11, #T_afafc_row1_col12, #T_afafc_row1_col13, #T_afafc_row1_col14, #T_afafc_row1_col15, #T_afafc_row1_col16, #T_afafc_row1_col17, #T_afafc_
, #T_afafc_row6_col25, #T_afafc_row6_col26, #T_afafc_row6_col27, #T_afafc_row7_col0, #T_afafc_row7_col1, #T_afafc_row7_col2, #T_afafc_row7_col19, #T_afafc_row7_col20, #T_afafc_row7_col21, #T_afafc_row7_col22, #T_afafc_row7_col23, #T_afafc_row7_col24, #T_afafc_row7_col25, #T_afafc_row7_col26, #T_afafc_row7_col27, #T_afafc_row8_col0, #T_afafc_row8_col1, #T_afafc_row8_col2, #T_afafc_row8_col8, #T_afafc_row8_col9, #T_afafc_row8_col10, #T_afafc_row8_col11, #T_afafc_row8_col12, #T_afafc_row8_col13, #T_afafc_row8_col19, #T_afafc_row8_col20, #T_afafc_row8_col21, #T_afafc_row8_col22, #T_afafc_row8_col23, #T_afafc_ro ...
#   font-size: 6pt;
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_afafc_row5_col3, #T_afafc_row8_col14 {
#   font-size: 6pt;
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_afafc_row5_col4 {
#   font-size: 6pt;
#   background-color: #b9b9b9;
#   color: #000000;
# }
# #T_afafc_row5_col5 {
#   font-size: 6pt;
#   background-color: #c1c1c1;
#   color: #000000;
# }
# #T_afafc_row5_col6 {
#   font-size: 6pt;
#   background-color: #858585;
#   color: #f1f1f1;
# }
# #T_afafc_row5_col7, #T_afafc_row5_col10, #T_afafc_row5_col11, #T_afafc_row5_col12, #T_afafc_row5_col13 {
#   font-size: 6pt;
#   background-color: #777777;
#   color: #f1f1f1;
# }
# #T_afafc_row5_col8 {
#   font-size: 6pt;
#   background-color: #090909;
#   color: #f1f1f1;
# }
# #T_afafc_row5_col9 {
#   font-size: 6pt;
#   background-color: #5b5b5b;
#   color: #f1f1f1;
# }
# #T_afafc_row5_col14 {
#   font-size: 6pt;
#   background-color: #919191;
#   color: #f1f1f1;
# }
# #T_afafc_row5_col15 {
#   font-size: 6pt;
#   background-color: #e1e1e1;
#   color: #000000;
# }
# #T_afafc_row6_col3 {
#   font-size: 6pt;
#   background-color: #727272;
#   color: #f1f1f1;
# }
# #T_afafc_row6_col4, #T_afafc_row6_col5, #T_afafc_row6_col6, #T_afafc_row6_col7, #T_afafc_row6_col8, #T_afafc_row6_col9, #T_afafc_row6_col10, #T_afafc_row6_col11, #T_afafc_row6_col12, #T_afafc_row6_col13, #T_afafc_row6_col14, #T_afafc_row7_col3, #T_afafc_row7_col4, #T_afafc_row7_col5, #T_afafc_row7_col6, #T_afafc_row7_col15, #T_afafc_row7_col16, #T_afafc_row7_col17, #T_afafc_row8_col16, #T_afafc_row8_col17, #T_afafc_row8_col18, #T_afafc_row9_col15, #T_afafc_row9_col16 {
#   font-size: 6pt;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_afafc_row6_col15 {
#   font-size: 6pt;
#   background-color: #020202;
#   color: #f1f1f1;
# }
# #T_afafc_row6_col16 {
#   font-size: 6pt;
#   background-color: #363636;
#   color: #f1f1f1;
# }
# #T_afafc_row6_col17 {
#   font-size: 6pt;
#   background-color: #9d9d9d;
#   color: #f1f1f1;
# }
# #T_afafc_row6_col18 {
#   font-size: 6pt;
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_afafc_row7_col7 {
#   font-size: 6pt;
#   background-color: #161616;
#   color: #f1f1f1;
# }
# #T_afafc_row7_col8, #T_afafc_row7_col9, #T_afafc_row7_col10, #T_afafc_row7_col11, #T_afafc_row7_col13 {
#   font-size: 6pt;
#   background-color: #535353;
#   color: #f1f1f1;
# }
# #T_afafc_row7_col12 {
#   font-size: 6pt;
#   background-color: #7c7c7c;
#   color: #f1f1f1;
# }
# #T_afafc_row7_col14 {
#   font-size: 6pt;
#   background-color: #3d3d3d;
#   color: #f1f1f1;
# }
# #T_afafc_row7_col18 {
#   font-size: 6pt;
#   background-color: #999999;
#   color: #f1f1f1;
# }
# #T_afafc_row8_col3 {
#   font-size: 6pt;
#   background-color: #eaeaea;
#   color: #000000;
# }
# #T_afafc_row8_col4 {
#   font-size: 6pt;
#   background-color: #d0d0d0;
#   color: #000000;
# }
# #T_afafc_row8_col5, #T_afafc_row8_col6 {
#   font-size: 6pt;
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_afafc_row8_col7 {
#   font-size: 6pt;
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_afafc_row8_col15 {
#   font-size: 6pt;
#   background-color: #232323;
#   color: #f1f1f1;
# }
# #T_afafc_row9_col14 {
#   font-size: 6pt;
#   background-color: #c2c2c2;
#   color: #000000;
# }
# #T_afafc_row9_col17 {
#   font-size: 6pt;
#   background-color: #080808;
#   color: #f1f1f1;
# }
# #T_afafc_row9_col18 {
#   font-size: 6pt;
#   background-color: #c4c4c4;
#   color: #000000;
# }
# </style>
# <table id="T_afafc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afafc_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_afafc_level0_col1" class="col_heading le

# %%
kernel = tensor([[-1., -1., -1.],
                 [ 0.,  0.,  0.],
                 [ 1.,  1.,  1.]]).float()

# %%
def apply_kernel(row, col, kernel):
    return (im3_t[row-1:row+2,col-1:col+2] * kernel).sum()

# %%
#| echo: false
#| output: true
#| eval: true
#| warning: false

cnn = sequential(
    nn.Conv2d(1, 30, kernel_size=3, stride=1, padding=1),
    nn.ReLU(),
    nn.Conv2d(30, 1, kernel_size=3, stride=1, padding=1)
)

# %%
#| echo: false
#| output: false
#| eval: true
#| warning: false

mnist = DataBlock(
    blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
    get_items=get_image_files,
    splitter=GrandparentSplitter(),
    get_y=parent_label,
    # item_tfms=Resize(28),
    # batch_tfms=Normalize()
)

dls = mnist.dataloaders(path_mnist)
xb,yb = first(dls.valid)

# %%
def conv(ni, nf, ks=3, act=True):
    res = nn.Conv2d(ni, nf, stride=2, kernel_size=ks, padding=ks//2)
    if act: res = nn.Sequential(res, nn.ReLU()) 
    return res

# %%
simple_cnn = sequential(
    conv(1, 4),   # Input: 28x28 -> Output: 14x14
    conv(4, 8),  # Input: 14x14 -> Output: 7x7
    conv(8, 16), # Input: 7x7 -> Output: 4x4
    conv(16, 32), # Input: 4x4 -> Output: 2x2
    conv(32, 2, act=False), # Input: 2x2 -> Output: 1x1
    Flatten()
)

# %%
learn = Learner(dls, simple_cnn, loss_func=F.cross_entropy, metrics=accuracy)
learn.summary()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Sequential (Input shape: 64 x 1 x 28 x 28)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      64 x 4 x 14 x 14
# Conv2d                                    40         True
# ReLU
# ____________________________________________________________________________
#                      64 x 8 x 7 x 7
# Conv2d                                    296        True
# ReLU
# ____________________________________________________________________________
#                      64 x 16 x 4 x 4
# Conv2d                                    1168       True
# ReLU
# ____________________________________________________________________________
#                      64 x 32 x 2 x 2
# Conv2d                                    4640       True
# ReLU
# ____________________________________________________________________________
#                      64 x 2 x 1 x 1
# Conv2d                                    578        True
# ____________________________________________________________________________
#                      64 x 2
# Flatten
# ____________________________________________________________________________
#
# Total params: 6,722
# Total trainable params: 6,722
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x7fe1df241a80>
# Loss function: <function cross_entropy at 0x7fe267dd9120>
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - Recorder
#   - ProgressCallback

# %%
learn.fit_one_cycle(2, 1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.075206</td>
#       <td>0.044281</td>
#       <td>0.985770</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.026854</td>
#       <td>0.037854</td>
#       <td>0.987733</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
#| echo: false
#| output: true
#| eval: true
#| warning: false
# path_mnist.ls()
path= untar_data(URLs.MNIST)
def get_dls(bs=64):
  return DataBlock(
      blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
      get_items=get_image_files,
      splitter=GrandparentSplitter('training', 'testing'),
      get_y=parent_label,
      # item_tfms=Resize(28),
      batch_tfms=Normalize()
  ).dataloaders(path, bs=bs)
dls = get_dls()
dls.show_batch(max_n=9, figsize=(4,4))

# %%
def simple_cnn():
  return sequential(
    conv(1, 8, 5),   # Input: 28x28 -> Output: 14x14
    conv(8, 16),  # Input: 14x14 -> Output: 7x7
    conv(16, 32), # Input: 7x7 -> Output: 4x4
    conv(32, 64), # Input: 4x4 -> Output: 2x2
    conv(64, 10, act=False), # Input: 2x2 -> Output: 1x1
    Flatten()
)

# %%
def fit(epochs=1):
    learn = Learner(dls, simple_cnn(), loss_func=F.cross_entropy, metrics=accuracy, cbs=ActivationStats(with_hist=True))
    learn.fit(epochs, 0.06)
    return learn

learn = fit()
# Out:
# /home/ec2-user/perso/.perso/lib/python3.11/site-packages/fastai/callback/core.py:71: UserWarning: You are shadowing an attribute (modules) that exists in the learner. Use `self.learn.modules` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.308629</td>
#       <td>2.309150</td>
#       <td>0.101000</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
from fastai.callback.hook import *
# learn.recorder.plot_loss()
learn.activation_stats.plot_layer_stats(0)
learn.activation_stats.plot_layer_stats(-2)

# %%
dls = get_dls(bs=512)
learn = fit()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.317569</td>
#       <td>2.303362</td>
#       <td>0.113500</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
#| echo: false
learn.activation_stats.plot_layer_stats(-2)

# %%
def fit(epochs=1):
    learn = Learner(dls, simple_cnn(), loss_func=F.cross_entropy, metrics=accuracy, cbs=ActivationStats(with_hist=True))
    learn.fit_one_cycle(epochs, 0.06)
    return learn

learn = fit()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.208017</td>
#       <td>0.077241</td>
#       <td>0.974300</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_sched()

# %%
#| echo: false
learn.activation_stats.plot_layer_stats(-2)

# %%
def conv(ni, nf, ks=3, act=True):
  layers = [nn.Conv2d(ni, nf, stride=2, kernel_size=ks, padding=ks//2)]
  layers.append(nn.BatchNorm2d(nf))
  if act: layers.append(nn.ReLU())
  return nn.Sequential(*layers)

# %%
#| echo: false
learn=fit()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.134557</td>
#       <td>0.055402</td>
#       <td>0.985800</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
